# %%
import speasy as spz
# %matplotlib widget
cda_tree = spz.inventories.tree.cda
# Use this instead if you are not using jupyterlab yet
#%matplotlib notebook
import matplotlib.pyplot as plt
from datetime import datetime

# %%
plt.figure()
mms1_fgm_b_gse_srvy=spz.get_data(cda_tree.MMS.MMS1.FGM.MMS1_FGM_SRVY_L2.mms1_fgm_b_gse_srvy_l2_clean, "2019-01-01", "2019-01-03")
mms1_fgm_b_gse_srvy.replace_fillval_by_nan().plot()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mms1_fgm_b_gse_srvy.meta
# Out:
# {'DIM_SIZES': [4],
#  'REPRESENTATION_1': 'represent_vec_tot',
#  'TENSOR_ORDER': [1],
#  'SI_CONVERSION': '1.0e-9>T',
#  'FIELDNAM': 'Magnetic field vector in GSE plus Btotal (8 or 16 S/s)',
#  'SCALETYP': 'linear',
#  'DEPEND_0': 'Epoch',
#  'LABL_PTR_1': ['Bx GSE', 'By GSE', 'Bz GSE', 'Bt    '],
#  'DISPLAY_TYPE': 'time_series',
#  'VALIDMIN': [-17000.0, -17000.0, -17000.0, 0.0],
#  'FILLVAL': [-9.999999848243207e+30],
#  'FORMAT': 'E13.5',
#  'UNITS': 'nT',
#  'CATDESC': 'Magnetic field vector in Geocentric Solar Ecliptic (GSE) cartesian coordinates plus Btotal (8 or 16 S/s)',
#  'VAR_TYPE': 'data',
#  'VALIDMAX': [17000.0, 17000.0, 17000.0, 17000.0],
#  'COORDINATE_SYSTEM': 'GSE'}

# %%
mms1_dis_energyspectr_omni_brst=spz.get_data(cda_tree.MMS.MMS1.DIS.MMS1_FPI_BRST_L2_DIS_MOMS.mms1_dis_energyspectr_omni_brst, "2019-01-02", "2019-01-03")

# %%
plt.figure()
mms1_dis_energyspectr_omni_brst.plot["matplotlib"].colormap(cmap='viridis')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.legend?
